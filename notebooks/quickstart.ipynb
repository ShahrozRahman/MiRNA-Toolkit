# %% [markdown]
# # miRNA-Toolkit Quickstart
# This notebook demonstrates alignment, quantification, prediction, disease lookup, and visualization entry points.

# %%
from mirna_toolkit import alignment, quantification, prediction, disease, visualization

print('Toolkit imported successfully')

# %%
example_counts = {'hsa-miR-21': 1250, 'hsa-miR-16': 900, 'hsa-miR-155': 250}
tpm_values = quantification.normalization.tpm(example_counts)
tpm_values
